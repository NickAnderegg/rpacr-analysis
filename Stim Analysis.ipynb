# %% [markdown]
# # Import dependencies

# %%
import pathlib
import json, csv
from pprint import pprint
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats import anova
from statsmodels.graphics.factorplots import interaction_plot

from scipy import stats

# %matplotlib inline

# %%
col_types = np.empty((0,), dtype=[
    ('trial', np.uint8),
    ('critical_target', np.unicode), ('critical_target_syllable', np.unicode),
    ('distractor', np.unicode), ('distractor_syllable', np.unicode),
    ('distractor_label', np.unicode),
    ('phon_sim', np.bool_), ('orth_sim', np.bool_),
    ('phon_distance', np.float64), ('orth_similarity', np.float64),
    ('phon_distance_normalized', np.float64), ('orth_similarity_normalized', np.float64),
    ('phon_distance_z', np.float64), ('orth_similarity_z', np.float64)
])

df = pd.DataFrame(col_types)

print(df.dtypes)
# Out:
# trial                           uint8
# critical_target                object
# critical_target_syllable       object
# distractor                     object
# distractor_syllable            object
# distractor_label               object
# phon_sim                         bool
# orth_sim                         bool
# phon_distance                 float64
# orth_similarity               float64
# phon_distance_normalized      float64
# orth_similarity_normalized    float64
# phon_distance_z               float64
# orth_similarity_z             float64
# dtype: object

# %% [markdown]
# # Load syllables
#
# Open the original raw, unfiltered dataset and extract the syllables that correspond with each character.

# %%
syllables = dict()

raw_file = pathlib.Path('stimuli/stimulus_set-01.csv')
with raw_file.open('r') as f:
    csvreader = csv.reader(f, delimiter='\t')
    
    for row in csvreader:
        if not row:
            continue
        
        if row[0] in syllables:
            continue
            
        syllables[row[0]] = row[1]
        
syllables_set = set(syllables.values())

print('Number unique characters:', len(syllables))
print('Number unique syllables:', len(syllables_set))
# Out:
# Number unique characters: 430
# Number unique syllables: 258

# %% [markdown]
# # Load trials
#
# Load trials from the actual trials.json file used in the experiment. Extract the stimulus sets and create a set of all characters used.

# %%
char_sets = []
all_chars = set()

row_count = 1

trials_file = pathlib.Path('stimuli/trials.json')
with trials_file.open('r') as f:
    trials = json.load(f)['sentences']
    
    for trial in trials:
        if 'original_distractors' in trial:
            key = 'original_distractors'
        else:
            key = 'distractors'
        
        # The actual character sets, indexed by the critical character
        values = trial[key]
        for label, character in values.items():
            phon_sim = np.bool(False)
            orth_sim = np.bool(False)
            
            if label == 'both_sim' or label == 'phon_sim':
                phon_sim = np.bool(True)
            if label == 'both_sim' or label == 'orth_sim':
                orth_sim = np.bool(True)
                
            
            df.loc[row_count] = [trial['sentence_number'], trial['critical_target'], "", character, "", label, phon_sim, orth_sim, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
            row_count += 1
            
        values['critical_target'] = trial['critical_target']
        char_sets.append(values)
        
        # A set containing all unique characters
        all_chars.update(trial[key].values())
        
    print('Number of stimulus sets loaded:    ', len(trials))
    print('Number of stimulus sets extracted: ', len(char_sets))
print('Number of uniqe characters:', len(all_chars))
# Out:
# Number of stimulus sets loaded:     96
# Number of stimulus sets extracted:  96
# Number of uniqe characters: 413

# %% [markdown]
# # Parse character comparisons

# %%
distances = dict()
max_orth_similarity = 0

distances_file = pathlib.Path('/Users/nick/github/orthophonology/data/char_comparisons.csv')
with distances_file.open('r') as f:
    csvreader = csv.reader(f)
    
    count = 0
    distances_count = 0
    for row in csvreader:
        if float(row[2]) > max_orth_similarity:
            max_orth_similarity = float(row[2])
        
        if row[0] in all_chars and row[1] in all_chars:
            chars = sorted(row[0:2])
            
            if chars[0] not in distances:
                distances[chars[0]] = {
                    chars[1]: row[2]
                }
                distances_count += 1
            else:
                distances[chars[0]][chars[1]] = row[2]
                distances_count += 1
                
        count += 1
        
    print('Rows parsed: ', count)
    print('Distances loaded: ', distances_count)
# Out:
# Rows parsed:  14669236
# Distances loaded:  81810

# %% [markdown]
# # Load syllable distances

# %%
syllable_distances = dict()
max_phon_distance = 0

syllable_distances_file = pathlib.Path('stimuli/distances.csv')
with syllable_distances_file.open('r') as f:
    csvreader = csv.reader(f)
    
    count = 0
    distances_count = 0
    for row in csvreader:
        if float(row[2]) > max_phon_distance:
            max_phon_distance = float(row[2])
        syls = sorted(row[:2])
        
        if syls[0] in syllables_set and syls[1] in syllables_set:
            if syls[0] not in syllable_distances:
                syllable_distances[syls[0]] = {
                    syls[1]: row[2]
                }
                distances_count += 1
            else:
                syllable_distances[syls[0]][syls[1]] = row[2]
                distances_count += 1
        count += 1
    print('Rows parsed: ', count)
    print('Distances loaded: ', distances_count)
# Out:
# Rows parsed:  2011015
# Distances loaded:  33411

# %% [markdown]
# # Join trials
#
# TODO: Investigate why there are a handful of missing comparisons

# %%
for i in range(1, len(df)+1):
    df.loc[i, 'critical_target_syllable'] = syllables[df.loc[i, 'critical_target']]
    df.loc[i, 'distractor_syllable'] = syllables[df.loc[i, 'distractor']]
    
    chars = sorted([df.loc[i, 'critical_target'], df.loc[i, 'distractor']])
    syls = sorted([df.loc[i, 'critical_target_syllable'], df.loc[i, 'distractor_syllable']])
    
    if chars[0] not in distances or chars[1] not in distances[chars[0]]:
        df.loc[i, 'orth_similarity'] = np.nan
        continue
    
    df.loc[i, 'orth_similarity'] = np.float64(distances[chars[0]][chars[1]])
    df.loc[i, 'phon_distance'] = np.float64(syllable_distances[syls[0]][syls[1]])
    
df
# Out:
#      trial critical_target critical_target_syllable distractor  \
# 1        1               柱                     zhu4          炷
# 2        1               柱                     zhu4          枉
# 3        1               柱                     zhu4          淹
# 4        1               柱                     zhu4          述
# 5        2               文                     wen2          汶
# 6        2               文                     wen2          这
# 7        2               文                     wen2          钙
# 8        2               文                     wen2          烷
# 9        3               殃                    yang1          秧
# 10       3               殃                    yang1          映
# 11       3               殃                    yang1          济
# 12       3               殃                    yang1          洋
# 13       4               秘                      mi4          铋
# 14       4               秘                      mi4          秧
# 15       4               秘                      mi4          璜
# 16       4               秘                      mi4          俪
# 17       5               拮                     jie2          诘
# 18       5               拮                     jie2          按
# 19       5               拮                     jie2          韵
# 20       5               拮                     jie2          邪
# 21       6               酩                    ming3          铭
# 22       6               酩                    ming3          铬
# 23       6               酩                    ming3          澳
# 24       6               酩                    ming3          明
# 25       7               息                      xi1          悉
# 26       7               息                      xi1          恙
# 27       7               息                      xi1          院
# 28       7               息                      xi1          戌
# 29       8               枉                    wang3          旺
# 30       8               枉                    wang3          析
# ..     ...             ...                      ...        ...
# 355     89               诽                     fei3          円
# 356     89               诽                     fei3          废
# 357     90               训                     xun4          巡
# 358     90               训                     xun4          讹
# 359     90               训                     xun4          腰
# 360     90               训                     xun4          迅
# 361     91               肢                     zhi1          吱
# 362     91               肢                     zhi1          听
# 363     91               肢                     zhi1          筵
# 364     91               肢                     zhi1          湿
# 365     92               棋                      qi2          骐
# 366     92               棋                      qi2          验
# 367     92               棋                      qi2          痒
# 368     92               棋                      qi2          脐
# 369     93               温                     wen1          榅
# 370     93               温                     wen1          愠
# 371     93               温                     wen1          汰
# 372     93               温                     wen1          闻
# 373     94               岗                    gang3          冈
# 374     94               岗                    gang3          区
# 375     94               岗                    gang3          意
# 376     94               岗                    gang3          港
# 377     95               宛                     wan3          苑
# 378     95               宛                     wan3          苛
# 379     95               宛                     wan3          羁
# 380     95               宛                     wan3          愿
# 381     96               任                     ren4          壬
# 382     96               任                     ren4          夭
# 383     96               任                     ren4          拽
# 384     96               任                     ren4          涔
#
#     distractor_syllable distractor_label phon_sim orth_sim  phon_distance  \
# 1                  zhu4         both_sim     True     True       0.000000
# 2                 wang3         orth_sim    False     True       1.593100
# 3                  yan1         both_dif    False    False       1.634290
# 4                  shu4         phon_sim     True    False       0.044500
# 5                  wen4         both_sim     True     True       0.150000
# 6                  zhe4         orth_sim    False     True       1.434195
# 7                  gai4         both_dif    False    False       1.591810
# 8                  wan2         phon_sim     True    False       0.129500
# 9                 yang1         both_sim     True     True       0.000000
# 10                ying4         orth_sim    False     True       0.585855
# 11                  ji4         both_dif    False    False       1.840550
# 12                yang2         phon_sim     True    False       0.075000
# 13                  bi4         both_sim     True     True       0.132685
# 14                yang1         orth_sim    False     True       1.575915
# 15               huang2         both_dif    False    False       1.431270
# 16                  li4         phon_sim     True    False       0.209250
# 17                 jie2         both_sim     True     True       0.000000
# 18                  an4         orth_sim    False     True       1.560225
# 19                 yun4         both_dif    False    False       1.634930
# 20                 xie2         phon_sim     True    False       0.044500
# 21                ming2         both_sim     True     True       0.075000
# 22                  ge4         orth_sim    False     True       1.013290
# 23                  ao4         both_dif    False    False       1.350945
# 24                ming2         phon_sim     True    False       0.075000
# 25                  xi1         both_sim     True     True       0.000000
# 26                yang4         orth_sim    False     True       1.816600
# 27                yuan4         both_dif    False    False       1.699890
# 28                  xu1         phon_sim     True    False       0.075000
# 29                wang4         both_sim     True     True       0.075000
# 30                  xi1         orth_sim    False     True       1.751055
# ..                  ...              ...      ...      ...            ...
# 355               yuan2         both_dif    False    False       1.387390
# 356                fei4         phon_sim     True    False       0.075000
# 357                xun2         both_sim     True     True       0.150000
# 358                  e2         orth_sim    False     True       1.479345
# 359                yao1         both_dif    False    False       1.650195
# 360                xun4         phon_sim     True    False       0.000000
# 361                zhi1         both_sim     True     True       0.000000
# 362               ting1         orth_sim    False     True       0.763990
# 363                yan2         both_dif    False    False       1.559760
# 364                shi1         phon_sim     True    False       0.044500
# 365                 qi2         both_sim     True     True       0.000000
# 366                yan4         orth_sim    False     True       1.623795
# 367               yang3         both_dif    False    False       1.667850
# 368                 qi2         phon_sim     True    False       0.000000
# 369                wen1         both_sim     True     True       0.000000
# 370                yun4         orth_sim    False     True       0.614080
# 371                tai4         both_dif    False    False       1.559510
# 372                wen2         phon_sim     True    False       0.075000
# 373               gang1         both_sim     True     True       0.150000
# 374                 qu1         orth_sim    False     True       1.051740
# 375                 yi4         both_dif    False    False       1.677245
# 376               gang3         phon_sim     True    False       0.000000
# 377               yuan4         both_sim     True     True       0.225000
# 378                 ke1         orth_sim    False     True       1.512865
# 379                 ji1         both_dif    False    False       1.658350
# 380               yuan4         phon_sim     True    False       0.225000
# 381                ren2         both_sim     True     True       0.150000
# 382                yao1         orth_sim    False     True       1.487365
# 383                 ye4         both_dif    False    False       1.228185
# 384                cen2         phon_sim     True    False       0.262525
#
#      orth_similarity  phon_distance_normalized  orth_similarity_normalized  \
# 1           0.833333                       NaN                         NaN
# 2           0.804444                       NaN                         NaN
# 3           0.069589                       NaN                         NaN
# 4           0.001111                       NaN                         NaN
# 5           0.800000                       NaN                         NaN
# 6           0.800000                       NaN                         NaN
# 7           0.037037                       NaN                         NaN
# 8           0.034632                       NaN                         NaN
# 9           0.716667                       NaN                         NaN
# 10          0.833333                       NaN                         NaN
# 11          0.054012                       NaN                         NaN
# 12          0.054012                       NaN                         NaN
# 13          0.770833                       NaN                         NaN
# 14          0.708333                       NaN                         NaN
# 15          0.030303                       NaN                         NaN
# 16          0.004724                       NaN                         NaN
# 17          0.437500                       NaN                         NaN
# 18          0.833333                       NaN                         NaN
# 19          0.016619                       NaN                         NaN
# 20          0.000000                       NaN                         NaN
# 21          0.686876                       NaN                         NaN
# 22          0.616363                       NaN                         NaN
# 23          0.038234                       NaN                         NaN
# 24          0.422684                       NaN                         NaN
# 25          0.746382                       NaN                         NaN
# 26          0.833333                       NaN                         NaN
# 27          0.021769                       NaN                         NaN
# 28          0.006944                       NaN                         NaN
# 29          0.833333                       NaN                         NaN
# 30          0.800000                       NaN                         NaN
# ..               ...                       ...                         ...
# 355         0.033333                       NaN                         NaN
# 356         0.026042                       NaN                         NaN
# 357         0.100000                       NaN                         NaN
# 358         0.777778                       NaN                         NaN
# 359         0.055556                       NaN                         NaN
# 360         0.066667                       NaN                         NaN
# 361         0.178571                       NaN                         NaN
# 362         0.178571                       NaN                         NaN
# 363         0.051852                       NaN                         NaN
# 364         0.132099                       NaN                         NaN
# 365         0.696970                       NaN                         NaN
# 366         0.553505                       NaN                         NaN
# 367         0.030303                       NaN                         NaN
# 368         0.043210                       NaN                         NaN
# 369         0.384615                       NaN                         NaN
# 370         0.500000                       NaN                         NaN
# 371         0.259259                       NaN                         NaN
# 372         0.088889                       NaN                         NaN
# 373         0.000000                       NaN                         NaN
# 374         0.000000                       NaN                         NaN
# 375         0.287139                       NaN                         NaN
# 376         0.061728                       NaN                         NaN
# 377         0.750000                       NaN                         NaN
# 378         0.583333                       NaN                         NaN
# 379         0.047020                       NaN                         NaN
# 380         0.035714                       NaN                         NaN
# 381         0.086806                       NaN                         NaN
# 382         0.086806                       NaN                         NaN
# 383         0.194444                       NaN                         NaN
# 384         0.101587                       NaN                         NaN
#
#      phon_distance_z  orth_similarity_z
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
# 9                NaN                NaN
# 10               NaN                NaN
# 11               NaN                NaN
# 12               NaN                NaN
# 13               NaN                NaN
# 14               NaN                NaN
# 15               NaN                NaN
# 16               NaN                NaN
# 17               NaN                NaN
# 18               NaN                NaN
# 19               NaN                NaN
# 20               NaN                NaN
# 21               NaN                NaN
# 22               NaN                NaN
# 23               NaN                NaN
# 24               NaN                NaN
# 25               NaN                NaN
# 26               NaN                NaN
# 27               NaN                NaN
# 28               NaN                NaN
# 29               NaN                NaN
# 30               NaN                NaN
# ..               ...                ...
# 355              NaN                NaN
# 356              NaN                NaN
# 357              NaN                NaN
# 358              NaN                NaN
# 359              NaN                NaN
# 360              NaN                NaN
# 361              NaN                NaN
# 362              NaN                NaN
# 363              NaN                NaN
# 364              NaN                NaN
# 365              NaN                NaN
# 366              NaN                NaN
# 367              NaN                NaN
# 368              NaN                NaN
# 369              NaN                NaN
# 370              NaN                NaN
# 371              NaN                NaN
# 372              NaN                NaN
# 373              NaN                NaN
# 374              NaN                NaN
# 375              NaN                NaN
# 376              NaN                NaN
# 377              NaN                NaN
# 378              NaN                NaN
# 379              NaN                NaN
# 380              NaN                NaN
# 381              NaN                NaN
# 382              NaN                NaN
# 383              NaN                NaN
# 384              NaN                NaN
#
# [384 rows x 14 columns]

# %% [raw]
# distractors = []
# for char_set in char_sets:
#     current_set = {
#         'critical_target': {
#             'orth': char_set['critical_target'],
#             'phon': syllables[char_set['critical_target']]
#         }
#     }
#
#     critical_target = char_set['critical_target']
#     critical_syllable = syllables[critical_target]
#
#     for label, char in char_set.items():
#         if label == 'critical_target':
#             continue
#
#         print(df.loc[(df['critical_target'] == critical_target) & (df['distractor'] == char)])
#
#         chars = sorted([critical_target, char])
#         char_syllable = syllables[char]
#
#         syls = sorted([char_syllable, critical_syllable])
#
#         syl_distance = syllable_distances[syls[0]][syls[1]]
#         if chars[0] not in distances:
# #             print(chars[0], ord(chars[0]), ' not in distances')
#             continue
#         elif chars[1] not in distances[chars[0]]:
# #             print(chars[1], ord(chars[1]), ' not in comparisons with ', chars[0], ord(chars[0]))
# #             if chars[1] in all_chars:
# #                 print(chars[1], ' is in all_chars')
#             continue
#
#         current_set[label] = {
#             'orth': (char, float(distances[chars[0]][chars[1]])),
#             'phon': (char_syllable, float(syl_distance))
#         }
#
#     distractors.append(current_set)

# %% [raw]
# distractor_scores = {
#     'both_sim': {
#         'orth': [],
#         'phon': []
#     },
#     'orth_sim': {
#         'orth': [],
#         'phon': []
#     },
#     'phon_sim': {
#         'orth': [],
#         'phon': []
#     },
#     'both_dif': {
#         'orth': [],
#         'phon': []
#     }
# }
#
# for group in distractors:
#     for key in distractor_scores.keys():
#         if key not in group:
#             continue
#         distractor_scores[key]['orth'].append(group[key]['orth'][1])
#         distractor_scores[key]['phon'].append(group[key]['phon'][1])

# %% [markdown]
# ## Normalize similarity and distancevalues

# %%
df['orth_similarity_normalized'] = df['orth_similarity'] / max_orth_similarity
df['phon_distance_normalized'] = df['phon_distance'] / max_phon_distance

# %% [markdown]
# # Compute z-scores

# %%
df['orth_similarity_z'] = (df['orth_similarity_normalized']-df['orth_similarity_normalized'].mean())/df['orth_similarity_normalized'].std()
df['phon_distance_z'] = (df['phon_distance_normalized']-df['phon_distance_normalized'].mean())/df['phon_distance_normalized'].std()

df
# Out:
#      trial critical_target critical_target_syllable distractor  \
# 1        1               柱                     zhu4          炷
# 2        1               柱                     zhu4          枉
# 3        1               柱                     zhu4          淹
# 4        1               柱                     zhu4          述
# 5        2               文                     wen2          汶
# 6        2               文                     wen2          这
# 7        2               文                     wen2          钙
# 8        2               文                     wen2          烷
# 9        3               殃                    yang1          秧
# 10       3               殃                    yang1          映
# 11       3               殃                    yang1          济
# 12       3               殃                    yang1          洋
# 13       4               秘                      mi4          铋
# 14       4               秘                      mi4          秧
# 15       4               秘                      mi4          璜
# 16       4               秘                      mi4          俪
# 17       5               拮                     jie2          诘
# 18       5               拮                     jie2          按
# 19       5               拮                     jie2          韵
# 20       5               拮                     jie2          邪
# 21       6               酩                    ming3          铭
# 22       6               酩                    ming3          铬
# 23       6               酩                    ming3          澳
# 24       6               酩                    ming3          明
# 25       7               息                      xi1          悉
# 26       7               息                      xi1          恙
# 27       7               息                      xi1          院
# 28       7               息                      xi1          戌
# 29       8               枉                    wang3          旺
# 30       8               枉                    wang3          析
# ..     ...             ...                      ...        ...
# 355     89               诽                     fei3          円
# 356     89               诽                     fei3          废
# 357     90               训                     xun4          巡
# 358     90               训                     xun4          讹
# 359     90               训                     xun4          腰
# 360     90               训                     xun4          迅
# 361     91               肢                     zhi1          吱
# 362     91               肢                     zhi1          听
# 363     91               肢                     zhi1          筵
# 364     91               肢                     zhi1          湿
# 365     92               棋                      qi2          骐
# 366     92               棋                      qi2          验
# 367     92               棋                      qi2          痒
# 368     92               棋                      qi2          脐
# 369     93               温                     wen1          榅
# 370     93               温                     wen1          愠
# 371     93               温                     wen1          汰
# 372     93               温                     wen1          闻
# 373     94               岗                    gang3          冈
# 374     94               岗                    gang3          区
# 375     94               岗                    gang3          意
# 376     94               岗                    gang3          港
# 377     95               宛                     wan3          苑
# 378     95               宛                     wan3          苛
# 379     95               宛                     wan3          羁
# 380     95               宛                     wan3          愿
# 381     96               任                     ren4          壬
# 382     96               任                     ren4          夭
# 383     96               任                     ren4          拽
# 384     96               任                     ren4          涔
#
#     distractor_syllable distractor_label phon_sim orth_sim  phon_distance  \
# 1                  zhu4         both_sim     True     True       0.000000
# 2                 wang3         orth_sim    False     True       1.593100
# 3                  yan1         both_dif    False    False       1.634290
# 4                  shu4         phon_sim     True    False       0.044500
# 5                  wen4         both_sim     True     True       0.150000
# 6                  zhe4         orth_sim    False     True       1.434195
# 7                  gai4         both_dif    False    False       1.591810
# 8                  wan2         phon_sim     True    False       0.129500
# 9                 yang1         both_sim     True     True       0.000000
# 10                ying4         orth_sim    False     True       0.585855
# 11                  ji4         both_dif    False    False       1.840550
# 12                yang2         phon_sim     True    False       0.075000
# 13                  bi4         both_sim     True     True       0.132685
# 14                yang1         orth_sim    False     True       1.575915
# 15               huang2         both_dif    False    False       1.431270
# 16                  li4         phon_sim     True    False       0.209250
# 17                 jie2         both_sim     True     True       0.000000
# 18                  an4         orth_sim    False     True       1.560225
# 19                 yun4         both_dif    False    False       1.634930
# 20                 xie2         phon_sim     True    False       0.044500
# 21                ming2         both_sim     True     True       0.075000
# 22                  ge4         orth_sim    False     True       1.013290
# 23                  ao4         both_dif    False    False       1.350945
# 24                ming2         phon_sim     True    False       0.075000
# 25                  xi1         both_sim     True     True       0.000000
# 26                yang4         orth_sim    False     True       1.816600
# 27                yuan4         both_dif    False    False       1.699890
# 28                  xu1         phon_sim     True    False       0.075000
# 29                wang4         both_sim     True     True       0.075000
# 30                  xi1         orth_sim    False     True       1.751055
# ..                  ...              ...      ...      ...            ...
# 355               yuan2         both_dif    False    False       1.387390
# 356                fei4         phon_sim     True    False       0.075000
# 357                xun2         both_sim     True     True       0.150000
# 358                  e2         orth_sim    False     True       1.479345
# 359                yao1         both_dif    False    False       1.650195
# 360                xun4         phon_sim     True    False       0.000000
# 361                zhi1         both_sim     True     True       0.000000
# 362               ting1         orth_sim    False     True       0.763990
# 363                yan2         both_dif    False    False       1.559760
# 364                shi1         phon_sim     True    False       0.044500
# 365                 qi2         both_sim     True     True       0.000000
# 366                yan4         orth_sim    False     True       1.623795
# 367               yang3         both_dif    False    False       1.667850
# 368                 qi2         phon_sim     True    False       0.000000
# 369                wen1         both_sim     True     True       0.000000
# 370                yun4         orth_sim    False     True       0.614080
# 371                tai4         both_dif    False    False       1.559510
# 372                wen2         phon_sim     True    False       0.075000
# 373               gang1         both_sim     True     True       0.150000
# 374                 qu1         orth_sim    False     True       1.051740
# 375                 yi4         both_dif    False    False       1.677245
# 376               gang3         phon_sim     True    False       0.000000
# 377               yuan4         both_sim     True     True       0.225000
# 378                 ke1         orth_sim    False     True       1.512865
# 379                 ji1         both_dif    False    False       1.658350
# 380               yuan4         phon_sim     True    False       0.225000
# 381                ren2         both_sim     True     True       0.150000
# 382                yao1         orth_sim    False     True       1.487365
# 383                 ye4         both_dif    False    False       1.228185
# 384                cen2         phon_sim     True    False       0.262525
#
#      orth_similarity  phon_distance_normalized  orth_similarity_normalized  \
# 1           0.833333                  0.000000                    0.882353
# 2           0.804444                  0.764350                    0.851765
# 3           0.069589                  0.784112                    0.073683
# 4           0.001111                  0.021351                    0.001176
# 5           0.800000                  0.071968                    0.847059
# 6           0.800000                  0.688109                    0.847059
# 7           0.037037                  0.763731                    0.039216
# 8           0.034632                  0.062133                    0.036669
# 9           0.716667                  0.000000                    0.758824
# 10          0.833333                  0.281086                    0.882353
# 11          0.054012                  0.883073                    0.057190
# 12          0.054012                  0.035984                    0.057190
# 13          0.770833                  0.063661                    0.816176
# 14          0.708333                  0.756105                    0.750000
# 15          0.030303                  0.686706                    0.032086
# 16          0.004724                  0.100396                    0.005002
# 17          0.437500                  0.000000                    0.463235
# 18          0.833333                  0.748577                    0.882353
# 19          0.016619                  0.784419                    0.017597
# 20          0.000000                  0.021351                    0.000000
# 21          0.686876                  0.035984                    0.727280
# 22          0.616363                  0.486164                    0.652619
# 23          0.038234                  0.648167                    0.040483
# 24          0.422684                  0.035984                    0.447548
# 25          0.746382                  0.000000                    0.790287
# 26          0.833333                  0.871582                    0.882353
# 27          0.021769                  0.815586                    0.023049
# 28          0.006944                  0.035984                    0.007353
# 29          0.833333                  0.035984                    0.882353
# 30          0.800000                  0.840135                    0.847059
# ..               ...                       ...                         ...
# 355         0.033333                  0.665653                    0.035294
# 356         0.026042                  0.035984                    0.027574
# 357         0.100000                  0.071968                    0.105882
# 358         0.777778                  0.709772                    0.823529
# 359         0.055556                  0.791743                    0.058824
# 360         0.066667                  0.000000                    0.070588
# 361         0.178571                  0.000000                    0.189076
# 362         0.178571                  0.366553                    0.189076
# 363         0.051852                  0.748354                    0.054902
# 364         0.132099                  0.021351                    0.139869
# 365         0.696970                  0.000000                    0.737968
# 366         0.553505                  0.779077                    0.586064
# 367         0.030303                  0.800214                    0.032086
# 368         0.043210                  0.000000                    0.045752
# 369         0.384615                  0.000000                    0.407240
# 370         0.500000                  0.294628                    0.529412
# 371         0.259259                  0.748234                    0.274510
# 372         0.088889                  0.035984                    0.094118
# 373         0.000000                  0.071968                    0.000000
# 374         0.000000                  0.504612                    0.000000
# 375         0.287139                  0.804722                    0.304029
# 376         0.061728                  0.000000                    0.065359
# 377         0.750000                  0.107952                    0.794118
# 378         0.583333                  0.725854                    0.617647
# 379         0.047020                  0.795656                    0.049786
# 380         0.035714                  0.107952                    0.037815
# 381         0.086806                  0.071968                    0.091912
# 382         0.086806                  0.713619                    0.091912
# 383         0.194444                  0.589268                    0.205882
# 384         0.101587                  0.125956                    0.107563
#
#      phon_distance_z  orth_similarity_z
# 1          -1.062884           1.476122
# 2           1.077205           1.390421
# 3           1.132537          -0.789602
# 4          -1.003105          -0.992748
# 5          -0.861381           1.377236
# 6           0.863740           1.377236
# 7           1.075472          -0.886171
# 8          -0.888920          -0.893305
# 9          -1.062884           1.130019
# 10         -0.275876           1.476122
# 11          1.409616          -0.835812
# 12         -0.962132          -0.835812
# 13         -0.884641           1.290710
# 14          1.054119           1.105297
# 15          0.859811          -0.906148
# 16         -0.781788          -0.982030
# 17         -1.062884           0.301843
# 18          1.033042           1.476122
# 19          1.133397          -0.946742
# 20         -1.003105          -0.996045
# 21         -0.962132           1.041641
# 22          0.298318           0.832458
# 23          0.751906          -0.882620
# 24         -0.962132           0.257891
# 25         -1.062884           1.218173
# 26          1.377443           1.476122
# 27          1.220661          -0.931466
# 28         -0.962132          -0.975443
# 29         -0.962132           1.476122
# 30          1.289393           1.377236
# ..               ...                ...
# 355         0.800864          -0.897158
# 356        -0.962132          -0.918789
# 357        -0.861381          -0.699385
# 358         0.924392           1.311311
# 359         1.153903          -0.831233
# 360        -1.062884          -0.798271
# 361        -1.062884          -0.466295
# 362        -0.036579          -0.466295
# 363         1.032417          -0.842221
# 364        -1.003105          -0.604160
# 365        -1.062884           1.071586
# 366         1.118439           0.645984
# 367         1.177620          -0.906148
# 368        -1.062884          -0.867858
# 369        -1.062884           0.144956
# 370        -0.237960           0.487256
# 371         1.032081          -0.226926
# 372        -0.962132          -0.732347
# 373        -0.861381          -0.996045
# 374         0.349970          -0.996045
# 375         1.190241          -0.144219
# 376        -1.062884          -0.812921
# 377        -0.760630           1.228906
# 378         0.969421           0.734472
# 379         1.164858          -0.856556
# 380        -0.760630          -0.890095
# 381        -0.861381          -0.738527
# 382         0.935166          -0.738527
# 383         0.586997          -0.419206
# 384        -0.710221          -0.694676
#
# [384 rows x 14 columns]

# %% [markdown]
# # Compute aggregate score

# %%
for phon_sim in {True, False}:
    for orth_sim in {True, False}:
        orth_multiplier =  1 if orth_sim else -1
        phon_multiplier = -1 if phon_sim else 1
        
        df.loc[(df2['phon_sim'] == phon_sim) & (df['orth_sim'] == orth_sim), 'agg_score'] = \
            ((phon_multiplier * df['phon_distance_z']) + ( orth_multiplier * df['orth_similarity_z'])) / 2

# %%
phon_ttest = stats.ttest_ind(
    df.loc[(df['phon_sim'] == False) & np.isfinite(df['phon_distance_z'])]['phon_distance_z'],
    df.loc[(df['phon_sim'] == True) & np.isfinite(df['phon_distance_z'])]['phon_distance_z']
)

phon_df = len(df.loc[np.isfinite(df['phon_distance_z'])]['phon_distance_z'])

phon_sim_mean = df.loc[(df['phon_sim'] == True) & np.isfinite(df['phon_distance_z'])]['phon_distance_z'].mean()
phon_dif_mean = df.loc[(df['phon_sim'] == False) & np.isfinite(df['phon_distance_z'])]['phon_distance_z'].mean()

phon_sim_std = df.loc[(df['phon_sim'] == True) & np.isfinite(df['phon_distance_z'])]['phon_distance_z'].std()
phon_dif_std = df.loc[(df['phon_sim'] == False) & np.isfinite(df['phon_distance_z'])]['phon_distance_z'].std()
    
print(
f'There was a significant difference in the phonological distance from the critical target '
f'for phonologically similar (M={phon_sim_mean:.3}, SD={phon_sim_std:.2}) '
f'and phonologically dissimilar (M={phon_dif_mean:.3}, SD={phon_dif_std:.2}) '
f'distractors; t({phon_df})={phon_ttest.statistic:.3}, p<{phon_ttest.pvalue:.3f}.'
)
# Out:
# There was a significant difference in the phonological distance from the critical target for phonologically similar (M=-0.937, SD=0.13) and phonologically dissimilar (M=0.917, SD=0.51) distractors; t(370)=47.7, p<0.000.

# %%
orth_ttest = stats.ttest_ind(
    df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'],
    df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z']
)

orth_df = len(df.loc[np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'])

orth_sim_mean = df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'].mean()
orth_dif_mean = df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'].mean()

orth_sim_std = df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'].std()
orth_dif_std = df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_z'])]['orth_similarity_z'].std()

print(
f'There was a significant difference in the orthographic distance from the critical target '
f'for orthographically similar (M={orth_sim_mean:.3}, SD={orth_sim_std:.2}) '
f'and orthographically dissimilar (M={orth_dif_mean:.3}, SD={orth_dif_std:.2}) '
f'distractors; t({orth_df})={orth_ttest.statistic:.3}, p<{orth_ttest.pvalue:.3f}.'
)
# Out:
# There was a significant difference in the orthographic distance from the critical target for orthographically similar (M=0.855, SD=0.71) and orthographically dissimilar (M=-0.845, SD=0.23) distractors; t(370)=-31.1, p<0.000.

# %%
orth_ttest = stats.ttest_ind(
    df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'],
    df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized']
)

orth_df = len(df.loc[np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'])

orth_sim_mean = df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'].mean()
orth_dif_mean = df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'].mean()

orth_sim_std = df.loc[(df['orth_sim'] == True) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'].std()
orth_dif_std = df.loc[(df['orth_sim'] == False) & np.isfinite(df['orth_similarity_normalized'])]['orth_similarity_normalized'].std()

print(
f'There was a significant difference in the orthographic distance from the critical target '
f'for orthographically similar (M={orth_sim_mean:.3}, SD={orth_sim_std:.3}) '
f'and orthographically dissimilar (M={orth_dif_mean:.3}, SD={orth_dif_std:.3}) '
f'distractors; t({orth_df})={orth_ttest.statistic:.3}, p<{orth_ttest.pvalue:.3f}.'
)
# Out:
# There was a significant difference in the orthographic distance from the critical target for orthographically similar (M=0.661, SD=0.253) and orthographically dissimilar (M=0.0538, SD=0.0816) distractors; t(370)=-31.1, p<0.000.

# %% [markdown]
# # Load SUBTLEX

# %%
subtlex_chr_file = pathlib.Path('/Users/nick/github/orthophonology/data/subtlex-ch/SUBTLEX-CH-CHR.csv')
with subtlex_chr_file.open('r') as f:
    subtlex_total_chr = next(f).split(': ')[1].replace(',', '').strip()
#     print(subtlex_total_chr)
    subtlex_total_chr_contexts = next(f).split(': ')[1].replace(',', '').strip()
#     print(subtlex_total_chr_contexts)
    
    subtlex = pd.read_csv(f, sep='\t')
subtlex.columns = ['character', 'count', 'per_million', 'log_count', 'context_count', 'context_percent', 'log_context_count']
subtlex
# Out:
#      character    count  per_million  log_count  context_count  \
# 0            我  2058980     43956.70     6.3137           6242
# 1            的  1762079     37618.23     6.2460           6243
# 2            你  1444831     30845.37     6.1598           6242
# 3            是  1172098     25022.86     6.0690           6243
# 4            了   993990     21220.47     5.9974           6243
# 5            不   904675     19313.70     5.9565           6243
# 6            们   701754     14981.59     5.8462           6243
# 7            这   633842     13531.75     5.8020           6243
# 8            一   604056     12895.86     5.7811           6240
# 9            他   564477     12050.89     5.7516           6242
# 10           么   557804     11908.43     5.7465           6227
# 11           在   546367     11664.27     5.7375           6242
# 12           有   533631     11392.37     5.7272           6243
# 13           个   452923      9669.35     5.6560           6242
# 14           好   412760      8811.92     5.6157           6242
# 15           来   377902      8067.74     5.5774           6242
# 16           人   373292      7969.33     5.5720           6240
# 17           那   365024      7792.81     5.5623           6239
# 18           要   355730      7594.40     5.5511           6243
# 19           会   321488      6863.37     5.5072           6242
# 20           就   313793      6699.10     5.4966           6243
# 21           什   307184      6558.00     5.4874           6239
# 22           没   293874      6273.85     5.4682           6241
# 23           到   290231      6196.08     5.4627           6243
# 24           说   281841      6016.96     5.4500           6243
# 25           吗   253338      5408.46     5.4037           6136
# 26           为   249231      5320.78     5.3966           6241
# 27           想   247453      5282.82     5.3935           6241
# 28           能   241617      5158.23     5.3831           6243
# 29           上   236451      5047.94     5.3737           6240
# ...        ...      ...          ...        ...            ...
# 5906         箬        1         0.02     0.0000              1
# 5907         忄        1         0.02     0.0000              1
# 5908         畳        1         0.02     0.0000              1
# 5909         広        1         0.02     0.0000              1
# 5910         瘈        1         0.02     0.0000              1
# 5911         谏        1         0.02     0.0000              1
# 5912         鉛        1         0.02     0.0000              1
# 5913         穫        1         0.02     0.0000              1
# 5914         冇        1         0.02     0.0000              1
# 5915         縮        1         0.02     0.0000              1
# 5916         俣        1         0.02     0.0000              1
# 5917         骯        1         0.02     0.0000              1
# 5918         跡        1         0.02     0.0000              1
# 5919         嬅        1         0.02     0.0000              1
# 5920         虧        1         0.02     0.0000              1
# 5921         姮        1         0.02     0.0000              1
# 5922         躍        1         0.02     0.0000              1
# 5923         睜        1         0.02     0.0000              1
# 5924         裎        1         0.02     0.0000              1
# 5925         筯        1         0.02     0.0000              1
# 5926         旽        1         0.02     0.0000              1
# 5927         钜        1         0.02     0.0000              1
# 5928         繫        1         0.02     0.0000              1
# 5929         洌        1         0.02     0.0000              1
# 5930         鈞        1         0.02     0.0000              1
# 5931         種        1         0.02     0.0000              1
# 5932         髙        1         0.02     0.0000              1
# 5933         筘        1         0.02     0.0000              1
# 5934         裥        1         0.02     0.0000              1
# 5935         汍        1         0.02     0.0000              1
#
#       context_percent  log_context_count
# 0               99.98             3.7953
# 1              100.00             3.7954
# 2               99.98             3.7953
# 3              100.00             3.7954
# 4              100.00             3.7954
# 5              100.00             3.7954
# 6              100.00             3.7954
# 7              100.00             3.7954
# 8               99.95             3.7952
# 9               99.98             3.7953
# 10              99.74             3.7943
# 11              99.98             3.7953
# 12             100.00             3.7954
# 13              99.98             3.7953
# 14              99.98             3.7953
# 15              99.98             3.7953
# 16              99.95             3.7952
# 17              99.94             3.7951
# 18             100.00             3.7954
# 19              99.98             3.7953
# 20             100.00             3.7954
# 21              99.94             3.7951
# 22              99.97             3.7953
# 23             100.00             3.7954
# 24             100.00             3.7954
# 25              98.29             3.7879
# 26              99.97             3.7953
# 27              99.97             3.7953
# 28             100.00             3.7954
# 29              99.95             3.7952
# ...               ...                ...
# 5906             0.02             0.0000
# 5907             0.02             0.0000
# 5908             0.02             0.0000
# 5909             0.02             0.0000
# 5910             0.02             0.0000
# 5911             0.02             0.0000
# 5912             0.02             0.0000
# 5913             0.02             0.0000
# 5914             0.02             0.0000
# 5915             0.02             0.0000
# 5916             0.02             0.0000
# 5917             0.02             0.0000
# 5918             0.02             0.0000
# 5919             0.02             0.0000
# 5920             0.02             0.0000
# 5921             0.02             0.0000
# 5922             0.02             0.0000
# 5923             0.02             0.0000
# 5924             0.02             0.0000
# 5925             0.02             0.0000
# 5926             0.02             0.0000
# 5927             0.02             0.0000
# 5928             0.02             0.0000
# 5929             0.02             0.0000
# 5930             0.02             0.0000
# 5931             0.02             0.0000
# 5932             0.02             0.0000
# 5933             0.02             0.0000
# 5934             0.02             0.0000
# 5935             0.02             0.0000
#
# [5936 rows x 7 columns]

# %% [markdown]
# # Add frequency data to DataFrame

# %%
for i in range(1, len(df)+1):
    if len(subtlex.loc[subtlex['character'] == df.loc[i, 'distractor']]['log_count']):
            df.loc[i, 'subtlex_log_count'] = np.float(subtlex.loc[subtlex['character'] == df.loc[i, 'distractor']]['log_count'])
            df.loc[i, 'subtlex_per_million'] = np.float(subtlex.loc[subtlex['character'] == df.loc[i, 'distractor']]['per_million'])
    else:
        df.loc[i, 'subtlex_log_count'] = np.float(0)
        df.loc[i, 'subtlex_per_million'] = np.float(0)
        
df['subtlex_log_per_million'] = df['subtlex_per_million'].apply(np.log10)
            
df.groupby('distractor_label').describe()[['subtlex_log_count', 'subtlex_per_million', 'subtlex_log_per_million']]
# Out:
#                         subtlex_log_count  subtlex_per_million  \
# distractor_label
# both_dif         count          96.000000            96.000000
#                  mean            2.329747           103.276979
#                  std             1.220735           340.217519
#                  min             0.301000             0.040000
#                  25%             1.434875             0.582500
#                  50%             2.213500             3.490000
#                  75%             3.225400            35.870000
#                  max             5.022800          2250.200000
# both_sim         count          96.000000            96.000000
#                  mean            2.199019            51.817917
#                  std             1.085340           188.975281
#                  min             0.000000             0.020000
#                  25%             1.249075             0.375000
#                  50%             2.203900             3.415000
#                  75%             2.872650            15.925000
#                  max             4.860100          1546.970000
# orth_sim         count          96.000000            96.000000
#                  mean            2.683477           323.999375
#                  std             1.245780          1458.955400
#                  min             0.000000             0.020000
#                  25%             1.730050             1.145000
#                  50%             2.414850             5.550000
#                  75%             3.612775            87.992500
#                  max             5.802000         13531.750000
# phon_sim         count          96.000000            96.000000
#                  mean            2.953521           211.614792
#                  std             1.155383           627.975244
#                  min             0.000000             0.000000
#                  25%             2.201150             3.395000
#                  50%             3.159000            30.845000
#                  75%             3.703950           108.127500
#                  max             5.396600          5320.780000
#
#                         subtlex_log_per_million
# distractor_label
# both_dif         count                96.000000
#                  mean                  0.656941
#                  std                   1.224251
#                  min                  -1.397940
#                  25%                  -0.235318
#                  50%                   0.542824
#                  75%                   1.554727
#                  max                   3.352221
# both_sim         count                96.000000
#                  mean                  0.527132
#                  std                   1.087888
#                  min                  -1.698970
#                  25%                  -0.426087
#                  50%                   0.533185
#                  75%                   1.201963
#                  max                   3.189482
# orth_sim         count                96.000000
#                  mean                  1.012749
#                  std                   1.246388
#                  min                  -1.698970
#                  25%                   0.058485
#                  50%                   0.744174
#                  75%                   1.942138
#                  max                   4.131354
# phon_sim         count                96.000000
#                  mean                      -inf
#                  std                        NaN
#                  min                       -inf
#                  25%                   0.530595
#                  50%                   1.488284
#                  75%                   2.033329
#                  max                   3.725975

# %%
for i in range(1, len(df)+1):
    df.loc[i, 'critical_subtlex_log_count'] = np.float(subtlex.loc[subtlex['character'] == df.loc[i, 'critical_target']]['log_count'])
    df.loc[i, 'critical_subtlex_per_million'] = np.float(subtlex.loc[subtlex['character'] == df.loc[i, 'critical_target']]['per_million'])

df['critical_subtlex_log_per_million'] = df['critical_subtlex_per_million'].apply(np.log10)
df.loc[df['distractor_label'] == 'both_sim'].describe()[['critical_subtlex_log_count', 'critical_subtlex_per_million', 'critical_subtlex_log_per_million']]
# Out:
#        critical_subtlex_log_count  critical_subtlex_per_million  \
# count                   96.000000                     96.000000
# mean                     3.075847                    133.221875
# std                      0.856883                    275.378292
# min                      0.845100                      0.150000
# 25%                      2.482900                      6.490000
# 50%                      2.946450                     18.870000
# 75%                      3.690025                    104.592500
# max                      4.843500                   1488.970000
#
#        critical_subtlex_log_per_million
# count                         96.000000
# mean                           1.405275
# std                            0.856707
# min                           -0.823909
# 25%                            0.812245
# 50%                            1.275758
# 75%                            2.019365
# max                            3.172886

# %%
df.groupby(['phon_sim', 'orth_sim']).describe()[['orth_similarity', 'phon_distance', 'orth_similarity_z', 'phon_distance_z']]
# Out:
#                          orth_similarity  phon_distance  orth_similarity_z  \
# phon_sim orth_sim
# False    False    count        94.000000      94.000000          94.000000
#                   mean          0.047558       1.633147          -0.854960
#                   std           0.051278       0.130766           0.152122
#                   min           0.000000       1.228185          -0.996045
#                   25%           0.018689       1.559906          -0.940602
#                   50%           0.037037       1.634610          -0.886171
#                   75%           0.059062       1.713300          -0.820830
#                   max           0.287139       1.889805          -0.144219
#          True     count        93.000000      93.000000          93.000000
#                   mean          0.614272       1.312163           0.826254
#                   std           0.247082       0.470771           0.732994
#                   min           0.000000       0.225000          -0.996045
#                   25%           0.500000       1.013290           0.487256
#                   50%           0.714444       1.512865           1.123427
#                   75%           0.804444       1.655150           1.390421
#                   max           0.916667       1.835600           1.723339
# True     False    count        92.000000      92.000000          92.000000
#                   mean          0.054091       0.084081          -0.835577
#                   std           0.096783       0.086297           0.287117
#                   min           0.000000       0.000000          -0.996045
#                   25%           0.000606       0.000000          -0.994247
#                   50%           0.025174       0.075000          -0.921365
#                   75%           0.056355       0.129500          -0.828861
#                   max           0.611111       0.315145           0.816878
#          True     count        91.000000      91.000000          91.000000
#                   mean          0.633565       0.104054           0.883491
#                   std           0.231509       0.104250           0.686795
#                   min           0.000000       0.000000          -0.996045
#                   25%           0.457673       0.000000           0.361689
#                   50%           0.732922       0.075000           1.178242
#                   75%           0.800000       0.150000           1.377236
#                   max           0.916667       0.451525           1.723339
#
#                          phon_distance_z
# phon_sim orth_sim
# False    False    count        94.000000
#                   mean          1.131001
#                   std           0.175664
#                   min           0.586997
#                   25%           1.032614
#                   50%           1.132967
#                   75%           1.238675
#                   max           1.475783
#          True     count        93.000000
#                   mean          0.699808
#                   std           0.632410
#                   min          -0.760630
#                   25%           0.298318
#                   50%           0.969421
#                   75%           1.160559
#                   max           1.402967
# True     False    count        92.000000
#                   mean         -0.949933
#                   std           0.115927
#                   min          -1.062884
#                   25%          -1.062884
#                   50%          -0.962132
#                   75%          -0.888920
#                   max          -0.639534
#          True     count        91.000000
#                   mean         -0.923103
#                   std           0.140044
#                   min          -1.062884
#                   25%          -1.062884
#                   50%          -0.962132
#                   75%          -0.861381
#                   max          -0.456328

# %% [raw]
# for group in distractor_scores.values():
#     raw_phon = group['phon']
#     max_phon = max(raw_phon)
#     min_phon = min(raw_phon)
#
#     normalized_phon = []
#     for value in raw_phon:
#         normalized_phon.append((value-min_phon)/(max_phon-min_phon))
#
#     group['phon_normalized'] = normalized_phon
#
#     raw_orth = group['orth']
#     max_orth = max(raw_orth)
#     min_orth = min(raw_orth)
#
#     normalized_orth = []
#     for value in raw_orth:
#         normalized_orth.append((value-min_orth)/(max_orth-min_orth))
#
#     group['orth_normalized'] = normalized_orth

# %% [raw]
# distractor_descriptives = {
#     'both_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'orth_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'phon_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'both_dif': {
#         'orth': 0,
#         'phon': 0
#     }
# }
#
# for group, val in distractor_scores.items():
#     for dim in val.keys():
#         distractor_descriptives[group][dim] = (
#             np.mean(distractor_scores[group][dim]),
#             np.std(distractor_scores[group][dim])
#         )
#
# pprint(distractor_descriptives)

# %% [raw]
# distractor_zscores = {
#     'both_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'orth_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'phon_sim': {
#         'orth': 0,
#         'phon': 0
#     },
#     'both_dif': {
#         'orth': 0,
#         'phon': 0
#     }
# }
#
# all_orth, all_phon = [], []
# for key, value in distractor_scores.items():
#     all_orth.extend(value['orth_normalized'])
#     all_phon.extend(value['phon_normalized'])
#
# orth_mean, orth_std = np.mean(all_orth), np.std(all_orth)
# phon_mean, phon_std = np.mean(all_phon), np.std(all_phon)
#
# for group, val in distractor_scores.items():
#     for dim in val.keys():
#         if dim == 'orth_normalized':
#             distractor_zscores[group]['orth'] = np.mean([(x-orth_mean)/orth_std for x in distractor_scores[group][dim]])
#         elif dim == 'phon_normalized':
#             distractor_zscores[group]['phon'] = np.mean([(x-phon_mean)/phon_std for x in distractor_scores[group][dim]])
#
# pprint(distractor_zscores)

# %% [raw]
# distractor_aggs = dict()
#
# distractor_aggs['both_sim'] = np.mean((distractor_zscores['both_sim']['orth'], (-1 * distractor_zscores['both_sim']['phon'])))
# distractor_aggs['orth_sim'] = np.mean((distractor_zscores['orth_sim']['orth'], distractor_zscores['orth_sim']['phon']))
# distractor_aggs['phon_sim'] = np.mean(((-1 * distractor_zscores['phon_sim']['orth']), (-1 * distractor_zscores['phon_sim']['phon'])))
# distractor_aggs['both_dif'] = np.mean(((-1 * distractor_zscores['both_dif']['orth']), distractor_zscores['both_dif']['phon']))
#
# pprint(distractor_aggs)
